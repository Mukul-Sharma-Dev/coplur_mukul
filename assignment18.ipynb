# %%
from pyspark.sql import SparkSession

def main():
    spark = SparkSession.builder.appName("PartitionDemo").getOrCreate()

    df = spark.range(0, 5000000)

    print("Initial partitions:", df.rdd.getNumPartitions())

    df_repartitioned = df.repartition(12)
    print("After repartition(12):", df_repartitioned.rdd.getNumPartitions())

    df_coalesced = df_repartitioned.coalesce(3)
    print("After coalesce(3):", df_coalesced.rdd.getNumPartitions())

    spark.stop()

if __name__ == "__main__":
    main()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/06/25 01:41:39 WARN Utils: Your hostname, Mukuls-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 172.16.24.69 instead (on interface en0)
# 26/06/25 01:41:39 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/25 01:41:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Initial partitions: 10
# [Stage 0:>                                                        (0 + 10) / 10]
# After repartition(12): 12
# After coalesce(3): 3
