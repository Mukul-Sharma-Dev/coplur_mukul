# %%
name = "Mukul"
age = 20

print("Name:", name, "Age:", age)
print("2026", "06", "01", sep="-")
print("Hello", end=" ")
print("World")
# Out:
# Name: Mukul Age: 20
# 2026-06-01
# Hello World

# %%
name = input("Enter your name: ")

print("Hello,", name + "! Welcome to Python.")
# Out:
# Hello, hunar! Welcome to Python.
